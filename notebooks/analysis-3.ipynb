# %%
from utils import * 
from blast import BLASTFileJSON 
from genbank import GenBankFile
from Bio.Align import PairwiseAligner
import itertools

# %%
# Want to look at all Methanoperedens in the samples which Betazoids are found in. 
# One approach could be to build a predictive model based on Methanoperedens strain presence. 

# Determining "negative" training cases. Ideally, I would want samples with Methanoperedens and/or Borgs, but no detectable Betazoids. 
# The first step will be to identify a set of marker genes which I can BLAST against the contigs in the sample to confirm that there 
# are no hits. So this whole thing probably needs to wait until I have those.
